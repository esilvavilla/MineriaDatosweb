# %% [markdown]
# # Clase 1: Introducción a la Minería de Datos en Astronomía

# %% [markdown]
# ## Objetivos del curso
# 1. Entender qué es la minería de datos en el contexto astronómico.
# 2. Familiarizarse con el entorno de control de versiones, usos de Google Colab y herramientas de machine learning.
# 3. Conocer y manejar algunas bases de datos de Astronomía

# %% [markdown]
# ## Evaluación del curso
# 1. Proyectos mensuales (4x10%)
# 2. Proyecto final (1x60%)

# %% [markdown]
# ## Profesores del curso
# 1. Germán Chaparro Molano (german.chaparro@udea.edu.co)
# 2. Esteban Silva Villa (esteban.silvav@udea.edu.co)

# %% [markdown]
# ## Horario del curso y aula de clase
# - El horario del curso será los lunes y miércoles de 2 a 4 de la tarde
# - El aula para el curso será la 5-104

# %% [markdown]
# ## Resumen del a información
# | Dato | info
# | --- | ---
# | Profesores | 1. Germán Chaparro Molano (german.chaparro@udea.edu.co)
# | | 2. Esteban Silva Villa (esteban.silvav@udea.edu.co)
# | Evaluación | Proyecto mensual (4x10%)
# | | Proyecto final (1x60%)
# | Aula | 5-104
# | Horario | LW 2-4PM

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Objetivos de hoy
# 1. Entender qué es la minería de datos en el contexto astronómico.
# 2. Familiarizarse con el entorno de Google Colab.
# 3. Verificar la instalación de librerías necesarias.

# %% [markdown]
# ## 1. El entorno Colab
# Google Colab es un entorno de Jupyter Notebook que se ejecuta en la nube. Nos permite escribir código y texto en el mismo documento.

# %%
print('Hola, Universo!')
# Out:
# Hola, Universo!

# %% [markdown]
# Podemos ejecutar comandos de sistema usando el signo de exclamación `!`.

# %%
# !python --version
# Out:
# Python 3.9.12

# %% [markdown]
# ## 2. Verificando Librerías
# Para este curso necesitaremos varias librerías. Verifiquemos si están instaladas.

# %%
import numpy
import pandas
import matplotlib
import astropy

print(f"Numpy version: {numpy.__version__}")
print(f"Astropy version: {astropy.__version__}")
try:
    import astroquery
    print(f"Astroquery version: {astroquery.__version__}")
except:
    print("Astroquery no está instalado por defecto.")
# Out:
# Numpy version: 1.26.4
# Astropy version: 5.0.4
# Astroquery version: 0.4.11

# %% [markdown]
# Si alguna librería falta, podemos instalarla con `pip`.

# %%
# !pip install astroquery

# %% [markdown]
# ## 3. Ejercicio Rápido
# Crea una lista con los nombres de los planetas y muéstrala.

# %%
planetas = ["Mercurio", "Venus", "Tierra", "Marte", "Júpiter", "Saturno", "Urano", "Neptuno"]
for p in planetas:
    print(p)
# Out:
# Mercurio
# Venus
# Tierra
# Marte
# Júpiter
# Saturno
# Urano
# Neptuno
